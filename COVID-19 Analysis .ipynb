# %%
#import libraries

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
# Reading csv file of India Covid 19
df=pd.read_csv(r"E:\THIRD YEAR\5TH SEM\Biomedical Instrumentation\Project\Data\India_COVID19.csv")
df.head()
# Out:
#          Date  Day  Month  Year  Cases  Deaths Country GeoId Country Code  \
# 0  12/31/2019   31     12  2019      0       0   India    IN          IND
# 1    1/1/2020    1      1  2020      0       0   India    IN          IND
# 2    1/2/2020    2      1  2020      0       0   India    IN          IND
# 3    1/3/2020    3      1  2020      0       0   India    IN          IND
# 4    1/4/2020    4      1  2020      0       0   India    IN          IND
#
#    Population Data 2019 Continent  \
# 0            1366417756      Asia
# 1            1366417756      Asia
# 2            1366417756      Asia
# 3            1366417756      Asia
# 4            1366417756      Asia
#
#    Cumulative number for 14 days of COVID-19 cases per 100000  Day Number
# 0                                                NaN                    1
# 1                                                NaN                    2
# 2                                                NaN                    3
# ...

# %%
df.tail()
# Out:
#           Date  Day  Month  Year  Cases  Deaths Country GeoId Country Code  \
# 193  7/12/2020   12      7  2020  28637     551   India    IN          IND
# 194  7/13/2020   13      7  2020  28701     500   India    IN          IND
# 195  7/14/2020   14      7  2020  28498     553   India    IN          IND
# 196  7/15/2020   15      7  2020  29429     582   India    IN          IND
# 197  7/16/2020   16      7  2020  32695     606   India    IN          IND
#
#      Population Data 2019 Continent  \
# 193            1366417756      Asia
# 194            1366417756      Asia
# 195            1366417756      Asia
# 196            1366417756      Asia
# 197            1366417756      Asia
#
#      Cumulative number for 14 days of COVID-19 cases per 100000  Day Number
# 193                                          23.469689                  194
# 194                                          24.146056                  195
# ...

# %%
x=df['Date']
y=df['Cases']

# %%
# Graph of Date Vs No. of cases
plt.xlabel('Date')
plt.ylabel('Cases')
plt.rcParams['figure.figsize']=(16,8)
plt.scatter(x,y)

# %%
s1=pd.Series(y)
s1
# Out:
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
#        ...
# 193    28637
# 194    28701
# 195    28498
# 196    29429
# 197    32695
# Name: Cases, Length: 198, dtype: int64

# %%
# Bar graph of no. of cases
s1.plot.bar(figsize=(16,8))
# Out:
# <AxesSubplot:>

# %%
# Graph of no. of deaths
s1.plot(figsize=(16,8))
# Out:
# <AxesSubplot:>

# %%
# Graph of No. of deaths Vs No. of cases
a=df['Cases']
b=df['Deaths']
plt.xlabel('Cases')
plt.ylabel('Deaths')
plt.scatter(a,b)

# %%
# Graph of Number of Deaths per day
s2=pd.Series(b)
s2.plot()
# Out:
# <AxesSubplot:>

# %%
# Reading csv file of China Covid 19
df2=pd.read_csv(r"E:\THIRD YEAR\5TH SEM\Biomedical Instrumentation\Project\Data\China_COVID19.csv")
df2.head()
# Out:
#          Date  Day  Month  Year  Cases  Deaths Country GeoId Country Code  \
# 0  12/31/2019   31     12  2019     27       0   China    CN          CHN
# 1    1/1/2020    1      1  2020      0       0   China    CN          CHN
# 2    1/2/2020    2      1  2020      0       0   China    CN          CHN
# 3    1/3/2020    3      1  2020     17       0   China    CN          CHN
# 4    1/4/2020    4      1  2020      0       0   China    CN          CHN
#
#    Population Data 2019 Continent  \
# 0            1433783692      Asia
# 1            1433783692      Asia
# 2            1433783692      Asia
# 3            1433783692      Asia
# 4            1433783692      Asia
#
#    Cumulative number for 14 days of COVID-19 cases per 100000
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# ...

# %%
p=df2['Cases']
q=df2['Deaths']
s3=pd.Series(p)
s4=pd.Series(q)

# %%
# Graph comparing deaths of India[Blue] Vs China[Red]
s2.plot()
s4.plot()
# Out:
# <AxesSubplot:>

# %%
#Graph comparing Covid 19 cases of India[Blue] Vs China[Red]
s1.plot()
s3.plot()
# Out:
# <AxesSubplot:>
